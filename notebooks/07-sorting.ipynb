# %%
import pandas as pd

# %%
people = {
    'first_name': ['John', 'Alice', 'Michael', 'Emma', 'Daniel', 'Olivia', 'Sophia', 'Matthew', 'Emily', 'David'],
    'last_name': ['Smith', 'Johnson', 'Williams', 'Brown', 'Jones', 'Garcia', 'Miller', 'Davis', 'Wilson', 'Taylor'],
    'email': ['john@example.com', 'alice@example.com', 'michael@example.com', 'emma@example.com', 'daniel@example.com',
              'olivia@example.com', 'sophia@example.com', 'matthew@example.com', 'emily@example.com', 'david@example.com'],
    'age': [25, 30, 35, 28, 32, 29, 31, 27, 33, 26],
    'weight': [70, 65, 75, 68, 73, 67, 72, 69, 71, 74],
    'country': ['USA', 'Canada', 'UK', 'Australia', 'Germany', 'Spain', 'France', 'Italy', 'Japan', 'Brazil']
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   first_name last_name                email  age  weight    country
# 0       John     Smith     john@example.com   25      70        USA
# 1      Alice   Johnson    alice@example.com   30      65     Canada
# 2    Michael  Williams  michael@example.com   35      75         UK
# 3       Emma     Brown     emma@example.com   28      68  Australia
# 4     Daniel     Jones   daniel@example.com   32      73    Germany
# 5     Olivia    Garcia   olivia@example.com   29      67      Spain
# 6     Sophia    Miller   sophia@example.com   31      72     France
# 7    Matthew     Davis  matthew@example.com   27      69      Italy
# 8      Emily    Wilson    emily@example.com   33      71      Japan
# 9      David    Taylor    david@example.com   26      74     Brazil

# %%
df.sort_values(by='age', ascending=False)
# Out:
#   first_name last_name                email  age  weight    country
# 2    Michael  Williams  michael@example.com   35      75         UK
# 8      Emily    Wilson    emily@example.com   33      71      Japan
# 4     Daniel     Jones   daniel@example.com   32      73    Germany
# 6     Sophia    Miller   sophia@example.com   31      72     France
# 1      Alice   Johnson    alice@example.com   30      65     Canada
# 5     Olivia    Garcia   olivia@example.com   29      67      Spain
# 3       Emma     Brown     emma@example.com   28      68  Australia
# 7    Matthew     Davis  matthew@example.com   27      69      Italy
# 9      David    Taylor    david@example.com   26      74     Brazil
# 0       John     Smith     john@example.com   25      70        USA

# %%
df.sort_values(by=['age', 'weight'])
# Out:
#   first_name last_name                email  age  weight    country
# 0       John     Smith     john@example.com   25      70        USA
# 9      David    Taylor    david@example.com   26      74     Brazil
# 7    Matthew     Davis  matthew@example.com   27      69      Italy
# 3       Emma     Brown     emma@example.com   28      68  Australia
# 5     Olivia    Garcia   olivia@example.com   29      67      Spain
# 1      Alice   Johnson    alice@example.com   30      65     Canada
# 6     Sophia    Miller   sophia@example.com   31      72     France
# 4     Daniel     Jones   daniel@example.com   32      73    Germany
# 8      Emily    Wilson    emily@example.com   33      71      Japan
# 2    Michael  Williams  michael@example.com   35      75         UK

# %%
df.sort_values(by=['age', 'weight'], ascending=[True, False])
# Out:
#   first_name last_name                email  age  weight    country
# 0       John     Smith     john@example.com   25      70        USA
# 9      David    Taylor    david@example.com   26      74     Brazil
# 7    Matthew     Davis  matthew@example.com   27      69      Italy
# 3       Emma     Brown     emma@example.com   28      68  Australia
# 5     Olivia    Garcia   olivia@example.com   29      67      Spain
# 1      Alice   Johnson    alice@example.com   30      65     Canada
# 6     Sophia    Miller   sophia@example.com   31      72     France
# 4     Daniel     Jones   daniel@example.com   32      73    Germany
# 8      Emily    Wilson    emily@example.com   33      71      Japan
# 2    Michael  Williams  michael@example.com   35      75         UK

# %%
df['email'].sort_values()
# Out:
# 1      alice@example.com
# 4     daniel@example.com
# 9      david@example.com
# 8      emily@example.com
# 3       emma@example.com
# 0       john@example.com
# 7    matthew@example.com
# 2    michael@example.com
# 5     olivia@example.com
# 6     sophia@example.com
# Name: email, dtype: object

# %% [markdown]
# ### Working on stackoverflow survey data

# %%
survey_df = pd.read_csv("survey_results_public.csv")

# %%
survey_df
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 0              1             I am a student who is learning to code      Yes
# 1              2             I am a student who is learning to code       No
# 2              3  I am not primarily a developer, but I write co...      Yes
# 3              4                     I am a developer by profession       No
# 4              5                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 9995       10039                     I am a developer by profession       No
# 9996       10040                     I am a developer by profession       No
# 9997       10041                     I am a developer by profession      Yes
# 9998       10042                     I am a developer by profession       No
# 9999       10043                     I am a developer by profession      Yes
#
# ...

# %%
filt = survey_df['Country'] == 'Iran'

# %%
programmers_from_iran = survey_df[filt].sort_values(by=['ConvertedComp'], ascending=False)

# %%
programmers_from_iran[['ConvertedComp', 'EdLevel']].head(50)
# Out:
#       ConvertedComp                                            EdLevel
# 2481        83150.0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 6778        34200.0        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 7792        33636.0                                                NaN
# 2569        31356.0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8449        30000.0  Secondary school (e.g. American high school, G...
# 6572        28500.0  Some college/university study without earning ...
# 6876        24228.0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 8795        22800.0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1149        22800.0        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4130        21372.0  Some college/university study without earning ...
# 5095        20064.0        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 1508        19956.0           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...
