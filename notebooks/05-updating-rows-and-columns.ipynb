# %%
import pandas as pd

# %%
people = {
    'first_name': ['John', 'Jane', 'Michael', 'Emily', 'David', 'Sarah', 'Daniel', 'Olivia', 'Matthew', 'Sophia', 'Christopher', 'Isabella', 'Andrew', 'Emma', 'James'],
    'last_name': ['Smith', 'Johnson', 'Williams', 'Jones', 'Brown', 'Davis', 'Miller', 'Wilson', 'Moore', 'Taylor', 'Anderson', 'Thomas', 'Jackson', 'White', 'Harris'],
    'email': ['john@example.com', 'jane@example.com', 'michael@example.com', 'emily@example.com', 'david@example.com', 'sarah@example.com', 'daniel@example.com', 'olivia@example.com', 'matthew@example.com', 'sophia@example.com', 'christopher@example.com', 'isabella@example.com', 'andrew@example.com', 'emma@example.com', 'james@example.com'],
    'country': ['USA', 'Canada', 'UK', 'Australia', 'Germany', 'France', 'Spain', 'Italy', 'Japan', 'China', 'Brazil', 'Mexico', 'India', 'South Africa', 'Russia'],
    'gender': ['M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M'],
    'age': [32, 28, 35, 42, 39, 31, 37, 26, 34, 29, 33, 27, 36, 30, 38]
}

# %%
df = pd.DataFrame(people)

# %% [markdown]
# ### Changing columns

# %%
df.columns = [column.upper() for column in df.columns]

# %%
df.columns
# Out:
# Index(['FIRST_NAME', 'LAST_NAME', 'EMAIL', 'COUNTRY', 'GENDER', 'AGE'], dtype='object')

# %%
df.columns = df.columns.str.replace('_', ' ')

# %%
df
# Out:
#      FIRST NAME LAST NAME                    EMAIL       COUNTRY GENDER  AGE
# 0          John     Smith         john@example.com           USA      M   32
# 1          Jane   Johnson         jane@example.com        Canada      F   28
# 2       Michael  Williams      michael@example.com            UK      M   35
# 3         Emily     Jones        emily@example.com     Australia      F   42
# 4         David     Brown        david@example.com       Germany      M   39
# 5         Sarah     Davis        sarah@example.com        France      F   31
# 6        Daniel    Miller       daniel@example.com         Spain      M   37
# 7        Olivia    Wilson       olivia@example.com         Italy      F   26
# 8       Matthew     Moore      matthew@example.com         Japan      M   34
# 9        Sophia    Taylor       sophia@example.com         China      F   29
# 10  Christopher  Anderson  christopher@example.com        Brazil      M   33
# 11     Isabella    Thomas     isabella@example.com        Mexico      F   27
# 12       Andrew   Jackson       andrew@example.com         India      M   36
# 13         Emma     White         emma@example.com  South Africa      F   30
# 14        James    Harris        james@example.com        Russia      M   38

# %% [markdown]
# Let's revert our changes.

# %%
df.columns = [column.lower() for column in df.columns.str.replace(' ', '_')]

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'email', 'country', 'gender', 'age'], dtype='object')

# %%
df
# Out:
#      first_name last_name                    email       country gender  age
# 0          John     Smith         john@example.com           USA      M   32
# 1          Jane   Johnson         jane@example.com        Canada      F   28
# 2       Michael  Williams      michael@example.com            UK      M   35
# 3         Emily     Jones        emily@example.com     Australia      F   42
# 4         David     Brown        david@example.com       Germany      M   39
# 5         Sarah     Davis        sarah@example.com        France      F   31
# 6        Daniel    Miller       daniel@example.com         Spain      M   37
# 7        Olivia    Wilson       olivia@example.com         Italy      F   26
# 8       Matthew     Moore      matthew@example.com         Japan      M   34
# 9        Sophia    Taylor       sophia@example.com         China      F   29
# 10  Christopher  Anderson  christopher@example.com        Brazil      M   33
# 11     Isabella    Thomas     isabella@example.com        Mexico      F   27
# 12       Andrew   Jackson       andrew@example.com         India      M   36
# 13         Emma     White         emma@example.com  South Africa      F   30
# 14        James    Harris        james@example.com        Russia      M   38

# %%
df.rename(columns={'gender': 'sex',})
# Out:
#      first_name last_name                    email       country sex  age
# 0          John     Smith         john@example.com           USA   M   32
# 1          Jane   Johnson         jane@example.com        Canada   F   28
# 2       Michael  Williams      michael@example.com            UK   M   35
# 3         Emily     Jones        emily@example.com     Australia   F   42
# 4         David     Brown        david@example.com       Germany   M   39
# 5         Sarah     Davis        sarah@example.com        France   F   31
# 6        Daniel    Miller       daniel@example.com         Spain   M   37
# 7        Olivia    Wilson       olivia@example.com         Italy   F   26
# 8       Matthew     Moore      matthew@example.com         Japan   M   34
# 9        Sophia    Taylor       sophia@example.com         China   F   29
# 10  Christopher  Anderson  christopher@example.com        Brazil   M   33
# 11     Isabella    Thomas     isabella@example.com        Mexico   F   27
# 12       Andrew   Jackson       andrew@example.com         India   M   36
# 13         Emma     White         emma@example.com  South Africa   F   30
# 14        James    Harris        james@example.com        Russia   M   38

# %% [markdown]
# ### Changing rows

# %%
df.loc[2] = ['John', 'Maxima', 'john@maxima.me', 'Turkey', 'M', 53]

# %%
df.loc[12, ['email']] = 'aj@micro.io'

# %%
df
# Out:
#      first_name last_name                    email       country gender  age
# 0          John     Smith         john@example.com           USA      M   32
# 1          Jane   Johnson         jane@example.com        Canada      F   28
# 2          John    Maxima           john@maxima.me        Turkey      M   53
# 3         Emily     Jones        emily@example.com     Australia      F   42
# 4         David     Brown        david@example.com       Germany      M   39
# 5         Sarah     Davis        sarah@example.com        France      F   31
# 6        Daniel    Miller       daniel@example.com         Spain      M   37
# 7        Olivia    Wilson       olivia@example.com         Italy      F   26
# 8       Matthew     Moore      matthew@example.com         Japan      M   34
# 9        Sophia    Taylor       sophia@example.com         China      F   29
# 10  Christopher  Anderson  christopher@example.com        Brazil      M   33
# 11     Isabella    Thomas     isabella@example.com        Mexico      F   27
# 12       Andrew   Jackson              aj@micro.io         India      M   36
# 13         Emma     White         emma@example.com  South Africa      F   30
# 14        James    Harris        james@example.com        Russia      M   38

# %%
df.at[2, 'last_name'] = 'Maxima Taximma'

# %%
df
# Out:
#      first_name       last_name                    email       country gender  \
# 0          John           Smith         john@example.com           USA      M
# 1          Jane         Johnson         jane@example.com        Canada      F
# 2          John  Maxima Taximma           john@maxima.me        Turkey      M
# 3         Emily           Jones        emily@example.com     Australia      F
# 4         David           Brown        david@example.com       Germany      M
# 5         Sarah           Davis        sarah@example.com        France      F
# 6        Daniel          Miller       daniel@example.com         Spain      M
# 7        Olivia          Wilson       olivia@example.com         Italy      F
# 8       Matthew           Moore      matthew@example.com         Japan      M
# 9        Sophia          Taylor       sophia@example.com         China      F
# 10  Christopher        Anderson  christopher@example.com        Brazil      M
# 11     Isabella          Thomas     isabella@example.com        Mexico      F
# 12       Andrew         Jackson              aj@micro.io         India      M
# 13         Emma           White         emma@example.com  South Africa      F
# 14        James          Harris        james@example.com        Russia      M
#
#     age
# 0    32
# 1    28
# 2    53
# 3    42
# 4    39
# 5    31
# 6    37
# 7    26
# 8    34
# 9    29
# 10   33
# 11   27
# 12   36
# 13   30
# 14   38

# %% [markdown]
# ### Note
# Prefer `at` over `loc`. It's faster.

# %% [markdown]
# ### Warning
# When filtering dataframe, you cannot use that dataframe to change values, because it's only a copy of dataframe.

# %%
filt = (df['email'] == 'aj@micro.io')

# %%
df[filt]['email'] = 'andjackson@micro.io'
# Out:
# /tmp/ipykernel_5396/1328301230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[filt]['email'] = 'andjackson@micro.io'

# %% [markdown]
# The right way is:

# %%
df.loc[filt, 'email'] = 'andjackson@micro.io'

# %%
df
# Out:
#      first_name       last_name                    email       country gender  \
# 0          John           Smith         john@example.com           USA      M
# 1          Jane         Johnson         jane@example.com        Canada      F
# 2          John  Maxima Taximma           john@maxima.me        Turkey      M
# 3         Emily           Jones        emily@example.com     Australia      F
# 4         David           Brown        david@example.com       Germany      M
# 5         Sarah           Davis        sarah@example.com        France      F
# 6        Daniel          Miller       daniel@example.com         Spain      M
# 7        Olivia          Wilson       olivia@example.com         Italy      F
# 8       Matthew           Moore      matthew@example.com         Japan      M
# 9        Sophia          Taylor       sophia@example.com         China      F
# 10  Christopher        Anderson  christopher@example.com        Brazil      M
# 11     Isabella          Thomas     isabella@example.com        Mexico      F
# 12       Andrew         Jackson      andjackson@micro.io         India      M
# 13         Emma           White         emma@example.com  South Africa      F
# 14        James          Harris        james@example.com        Russia      M
#
#     age
# 0    32
# 1    28
# 2    53
# 3    42
# 4    39
# 5    31
# 6    37
# 7    26
# 8    34
# 9    29
# 10   33
# 11   27
# 12   36
# 13   30
# 14   38

# %% [markdown]
# ### Updating all rows at once

# %%
df['gender'] = df['gender'].str.lower()

# %%
df
# Out:
#      first_name       last_name                    email       country gender  \
# 0          John           Smith         john@example.com           USA      m
# 1          Jane         Johnson         jane@example.com        Canada      f
# 2          John  Maxima Taximma           john@maxima.me        Turkey      m
# 3         Emily           Jones        emily@example.com     Australia      f
# 4         David           Brown        david@example.com       Germany      m
# 5         Sarah           Davis        sarah@example.com        France      f
# 6        Daniel          Miller       daniel@example.com         Spain      m
# 7        Olivia          Wilson       olivia@example.com         Italy      f
# 8       Matthew           Moore      matthew@example.com         Japan      m
# 9        Sophia          Taylor       sophia@example.com         China      f
# 10  Christopher        Anderson  christopher@example.com        Brazil      m
# 11     Isabella          Thomas     isabella@example.com        Mexico      f
# 12       Andrew         Jackson      andjackson@micro.io         India      m
# 13         Emma           White         emma@example.com  South Africa      f
# 14        James          Harris        james@example.com        Russia      m
#
#     age
# 0    32
# 1    28
# 2    53
# 3    42
# 4    39
# 5    31
# 6    37
# 7    26
# 8    34
# 9    29
# 10   33
# 11   27
# 12   36
# 13   30
# 14   38

# %% [markdown]
# ### Upadating rows in an advanced way
#
# These methods are used when updating all rows:
#
# - `apply`: Used on calling functions on our values. Works both with dataframe and series.
# - `map`: Only works on series.
# - `applymap`: It's deprecated. Use `map`.
# - `replace`: It's like `map`, but only works on selected items.

# %%
df['email'].apply(len)
# Out:
# 0     16
# 1     16
# 2     14
# 3     17
# 4     17
# 5     17
# 6     18
# 7     18
# 8     19
# 9     18
# 10    23
# 11    20
# 12    19
# 13    16
# 14    17
# Name: email, dtype: int64

# %%
def update_gender(gender):
    if gender == 'm':
        return 'Male'
    return 'Female'

# %%
df['gender'] = df['gender'].apply(update_gender)

# %%
df
# Out:
#      first_name       last_name                    email       country  \
# 0          John           Smith         john@example.com           USA
# 1          Jane         Johnson         jane@example.com        Canada
# 2          John  Maxima Taximma           john@maxima.me        Turkey
# 3         Emily           Jones        emily@example.com     Australia
# 4         David           Brown        david@example.com       Germany
# 5         Sarah           Davis        sarah@example.com        France
# 6        Daniel          Miller       daniel@example.com         Spain
# 7        Olivia          Wilson       olivia@example.com         Italy
# 8       Matthew           Moore      matthew@example.com         Japan
# 9        Sophia          Taylor       sophia@example.com         China
# 10  Christopher        Anderson  christopher@example.com        Brazil
# 11     Isabella          Thomas     isabella@example.com        Mexico
# 12       Andrew         Jackson      andjackson@micro.io         India
# 13         Emma           White         emma@example.com  South Africa
# 14        James          Harris        james@example.com        Russia
#
#     gender  age
# 0     Male   32
# 1   Female   28
# 2     Male   53
# 3   Female   42
# 4     Male   39
# 5   Female   31
# 6     Male   37
# 7   Female   26
# 8     Male   34
# 9   Female   29
# 10    Male   33
# 11  Female   27
# 12    Male   36
# 13  Female   30
# 14    Male   38

# %%
df['gender'] = df['gender'].apply(lambda gender: gender.lower())

# %%
df
# Out:
#      first_name       last_name                    email       country  \
# 0          John           Smith         john@example.com           USA
# 1          Jane         Johnson         jane@example.com        Canada
# 2          John  Maxima Taximma           john@maxima.me        Turkey
# 3         Emily           Jones        emily@example.com     Australia
# 4         David           Brown        david@example.com       Germany
# 5         Sarah           Davis        sarah@example.com        France
# 6        Daniel          Miller       daniel@example.com         Spain
# 7        Olivia          Wilson       olivia@example.com         Italy
# 8       Matthew           Moore      matthew@example.com         Japan
# 9        Sophia          Taylor       sophia@example.com         China
# 10  Christopher        Anderson  christopher@example.com        Brazil
# 11     Isabella          Thomas     isabella@example.com        Mexico
# 12       Andrew         Jackson      andjackson@micro.io         India
# 13         Emma           White         emma@example.com  South Africa
# 14        James          Harris        james@example.com        Russia
#
#     gender  age
# 0     male   32
# 1   female   28
# 2     male   53
# 3   female   42
# 4     male   39
# 5   female   31
# 6     male   37
# 7   female   26
# 8     male   34
# 9   female   29
# 10    male   33
# 11  female   27
# 12    male   36
# 13  female   30
# 14    male   38

# %%
df.apply(len)
# Out:
# first_name    15
# last_name     15
# email         15
# country       15
# gender        15
# age           15
# dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0     6
# 1     6
# 2     6
# 3     6
# 4     6
# 5     6
# 6     6
# 7     6
# 8     6
# 9     6
# 10    6
# 11    6
# 12    6
# 13    6
# 14    6
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first_name                 Andrew
# last_name                Anderson
# email         andjackson@micro.io
# country                 Australia
# gender                     female
# age                            26
# dtype: object

# %%
df.apply(lambda series_ojb: series_ojb.max())
# Out:
# first_name                Sophia
# last_name                 Wilson
# email         sophia@example.com
# country                      USA
# gender                      male
# age                           53
# dtype: object

# %%
df.applymap(type)
# Out:
# /tmp/ipykernel_5396/3828366062.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(type)
#        first_name      last_name          email        country         gender  \
# 0   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 1   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 2   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 3   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 4   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 5   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 6   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 7   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 8   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 9   <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 10  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 11  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 12  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 13  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# 14  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
#
#               age
# 0   <class 'int'>
# 1   <class 'int'>
# 2   <class 'int'>
# 3   <class 'int'>
# 4   <class 'int'>
# 5   <class 'int'>
# 6   <class 'int'>
# 7   <class 'int'>
# 8   <class 'int'>
# 9   <class 'int'>
# 10  <class 'int'>
# 11  <class 'int'>
# 12  <class 'int'>
# 13  <class 'int'>
# 14  <class 'int'>

# %%
df
# Out:
#      first_name       last_name                    email       country  \
# 0          John           Smith         john@example.com           USA
# 1          Jane         Johnson         jane@example.com        Canada
# 2          John  Maxima Taximma           john@maxima.me        Turkey
# 3         Emily           Jones        emily@example.com     Australia
# 4         David           Brown        david@example.com       Germany
# 5         Sarah           Davis        sarah@example.com        France
# 6        Daniel          Miller       daniel@example.com         Spain
# 7        Olivia          Wilson       olivia@example.com         Italy
# 8       Matthew           Moore      matthew@example.com         Japan
# 9        Sophia          Taylor       sophia@example.com         China
# 10  Christopher        Anderson  christopher@example.com        Brazil
# 11     Isabella          Thomas     isabella@example.com        Mexico
# 12       Andrew         Jackson      andjackson@micro.io         India
# 13         Emma           White         emma@example.com  South Africa
# 14        James          Harris        james@example.com        Russia
#
#     gender  age
# 0     male   32
# 1   female   28
# 2     male   53
# 3   female   42
# 4     male   39
# 5   female   31
# 6     male   37
# 7   female   26
# 8     male   34
# 9   female   29
# 10    male   33
# 11  female   27
# 12    male   36
# 13  female   30
# 14    male   38

# %%
df['last_name'].map({'Brown': 'Yellow', 'Taylor': 'Jeferson'})
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4       Yellow
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9     Jeferson
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# Name: last_name, dtype: object

# %%
df['last_name'].replace({'Brown': 'Yellow', 'Taylor': 'Jeferson'})
# Out:
# 0              Smith
# 1            Johnson
# 2     Maxima Taximma
# 3              Jones
# 4             Yellow
# 5              Davis
# 6             Miller
# 7             Wilson
# 8              Moore
# 9           Jeferson
# 10          Anderson
# 11            Thomas
# 12           Jackson
# 13             White
# 14            Harris
# Name: last_name, dtype: object

# %%
df.rename(columns={'gender': 'sex'}, inplace=True)

# %%
df
# Out:
#      first_name       last_name                    email       country  \
# 0          John           Smith         john@example.com           USA
# 1          Jane         Johnson         jane@example.com        Canada
# 2          John  Maxima Taximma           john@maxima.me        Turkey
# 3         Emily           Jones        emily@example.com     Australia
# 4         David           Brown        david@example.com       Germany
# 5         Sarah           Davis        sarah@example.com        France
# 6        Daniel          Miller       daniel@example.com         Spain
# 7        Olivia          Wilson       olivia@example.com         Italy
# 8       Matthew           Moore      matthew@example.com         Japan
# 9        Sophia          Taylor       sophia@example.com         China
# 10  Christopher        Anderson  christopher@example.com        Brazil
# 11     Isabella          Thomas     isabella@example.com        Mexico
# 12       Andrew         Jackson      andjackson@micro.io         India
# 13         Emma           White         emma@example.com  South Africa
# 14        James          Harris        james@example.com        Russia
#
#        sex  age
# 0     male   32
# 1   female   28
# 2     male   53
# 3   female   42
# 4     male   39
# 5   female   31
# 6     male   37
# 7   female   26
# 8     male   34
# 9   female   29
# 10    male   33
# 11  female   27
# 12    male   36
# 13  female   30
# 14    male   38
