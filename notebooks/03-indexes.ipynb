# %%
import pandas as pd

# %%
people = {
    "first_name": ["Mosh", "Kim", "Ted"],
    "last_name": ["Hamedani", "Black", "Beneky"],
    "email": ["mosh@hamedan.ir", "kblack@google.com", "tbnk@lg.co"]
}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#   first_name last_name              email
# 0       Mosh  Hamedani    mosh@hamedan.ir
# 1        Kim     Black  kblack@google.com
# 2        Ted    Beneky         tbnk@lg.co

# %%
df.set_index('email')
# Out:
#                   first_name last_name
# email
# mosh@hamedan.ir         Mosh  Hamedani
# kblack@google.com        Kim     Black
# tbnk@lg.co               Ted    Beneky

# %%
df
# Out:
#   first_name last_name              email
# 0       Mosh  Hamedani    mosh@hamedan.ir
# 1        Kim     Black  kblack@google.com
# 2        Ted    Beneky         tbnk@lg.co

# %%
df.set_index('email', inplace=True)

# %%
df
# Out:
#                   first_name last_name
# email
# mosh@hamedan.ir         Mosh  Hamedani
# kblack@google.com        Kim     Black
# tbnk@lg.co               Ted    Beneky

# %%
df.index
# Out:
# Index(['mosh@hamedan.ir', 'kblack@google.com', 'tbnk@lg.co'], dtype='object', name='email')

# %%
df.loc['mosh@hamedan.ir', ['first_name', 'last_name']]
# Out:
# first_name        Mosh
# last_name     Hamedani
# Name: mosh@hamedan.ir, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#                email first_name last_name
# 0    mosh@hamedan.ir       Mosh  Hamedani
# 1  kblack@google.com        Kim     Black
# 2         tbnk@lg.co        Ted    Beneky

# %% [markdown]
# You can also set index when creating a dataframe.

# %%
df = pd.read_csv("survey_results_public.csv", index_col="Respondent")

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 10039                          I am a developer by profession       No
# 10040                          I am a developer by profession       No
# 10041                          I am a developer by profession      Yes
# 10042                          I am a developer by profession       No
# 10043                          I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 1                                                       Never
# 2                                     Less than once per year
# 3                                                       Never
# 4                                                       Never
# 5                                  Once a month or more often
# ...                                                       ...
# 10039                                                   Never
# 10040       Less than once a month but more than once per ...
# 10041       Less than once a month but more than once per ...
# 10042                                                   Never
# 10043       Less than once a month but more than once per ...
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# 4           The quality of OSS and closed source software ...
# 5           OSS is, on average, of HIGHER quality than pro...
# ...                                                       ...
# 10039       The quality of OSS and closed source software ...
# 10040       OSS is, on average, of HIGHER quality than pro...
# 10041       The quality of OSS and closed source software ...
# 10042       OSS is, on average, of HIGHER quality than pro...
# 10043       The quality of OSS and closed source software ...
#
#                                         Employment                 Country  \
# Respondent
# 1           Not employed, and not looking for work          United Kingdom
# 2               Not employed, but looking for work  Bosnia and Herzegovina
# 3                               Employed full-time                Thailand
# 4                               Employed full-time           United States
# 5                               Employed full-time                 Ukraine
# ...                                            ...                     ...
# 10039                           Employed full-time           United States
# 10040                           Employed full-time                   India
# 10041                           Employed full-time           United States
# 10042                           Employed full-time                Colombia
# 10043                           Employed full-time                  Canada
#
#                    Student                                            EdLevel  \
# Respondent
# 1                       No                          Primary/elementary school
# 2           Yes, full-time  Secondary school (e.g. American high school, G...
# 3                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 5                       No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                    ...                                                ...
# 10039                   No  Some college/university study without earning ...
# 10040                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10041                   No  Some college/university study without earning ...
# 10042                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10043                   No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                                UndergradMajor  \
# Respondent
# 1                                                         NaN
# 2                                                         NaN
# 3                               Web development or web design
# 4           Computer science, computer engineering, or sof...
# 5           Computer science, computer engineering, or sof...
# ...                                                       ...
# 10039       Computer science, computer engineering, or sof...
# 10040       Computer science, computer engineering, or sof...
# 10041       Fine arts or performing arts (ex. graphic desi...
# 10042       Computer science, computer engineering, or sof...
# 10043       Computer science, computer engineering, or sof...
#
#                                                      EduOther  ...  \
# Respondent                                                     ...
# 1           Taught yourself a new language, framework, or ...  ...
# 2           Taken an online course in programming or softw...  ...
# 3           Taught yourself a new language, framework, or ...  ...
# 4           Taken an online course in programming or softw...  ...
# 5           Taken an online course in programming or softw...  ...
# ...                                                       ...  ...
# 10039       Taken an online course in programming or softw...  ...
# 10040       Taken an online course in programming or softw...  ...
# 10041       Taught yourself a new language, framework, or ...  ...
# 10042       Taken an online course in programming or softw...  ...
# 10043       Taken an online course in programming or softw...  ...
#
#                                       WelcomeChange  \
# Respondent
# 1           Just as welcome now as I felt last year
# 2           Just as welcome now as I felt last year
# 3           Just as welcome now as I felt last year
# 4           Just as welcome now as I felt last year
# 5           Just as welcome now as I felt last year
# ...                                             ...
# 10039       Just as welcome now as I felt last year
# 10040       Just as welcome now as I felt last year
# 10041       Just as welcome now as I felt last year
# 10042                                           NaN
# 10043       Just as welcome now as I felt last year
#
#                                                  SONewContent   Age Gender  \
# Respondent
# 1           Tech articles written by other developers;Indu...  14.0    Man
# 2           Tech articles written by other developers;Indu...  19.0    Man
# 3           Tech meetups or events in your area;Courses on...  28.0    Man
# 4           Tech articles written by other developers;Indu...  22.0    Man
# 5           Tech meetups or events in your area;Courses on...  30.0    Man
# ...                                                       ...   ...    ...
# 10039                                                     NaN  25.0    Man
# 10040       Tech articles written by other developers;Tech...  28.0    Man
# 10041       Tech articles written by other developers;Cour...  28.0    Man
# 10042       Tech articles written by other developers;Indu...  39.0    Man
# 10043       Tech articles written by other developers;Cour...  25.0    Man
#
#            Trans                Sexuality  \
# Respondent
# 1             No  Straight / Heterosexual
# 2             No  Straight / Heterosexual
# 3             No  Straight / Heterosexual
# 4             No  Straight / Heterosexual
# 5             No  Straight / Heterosexual
# ...          ...                      ...
# 10039         No  Straight / Heterosexual
# 10040         No  Straight / Heterosexual
# 10041         No  Straight / Heterosexual
# 10042         No  Straight / Heterosexual
# 10043         No  Straight / Heterosexual
#
#                                                     Ethnicity Dependents  \
# Respondent
# 1                                                         NaN         No
# 2                                                         NaN         No
# 3                                                         NaN        Yes
# 4                                White or of European descent         No
# 5                    White or of European descent;Multiracial         No
# ...                                                       ...        ...
# 10039                            White or of European descent         No
# 10040                                             South Asian        Yes
# 10041                            White or of European descent         No
# 10042                               Hispanic or Latino/Latina        Yes
# 10043       Hispanic or Latino/Latina;White or of European...        Yes
#
#                      SurveyLength                  SurveyEase
# Respondent
# 1           Appropriate in length  Neither easy nor difficult
# 2           Appropriate in length  Neither easy nor difficult
# 3           Appropriate in length  Neither easy nor difficult
# 4           Appropriate in length                        Easy
# 5           Appropriate in length                        Easy
# ...                           ...                         ...
# 10039       Appropriate in length                        Easy
# 10040       Appropriate in length                        Easy
# 10041       Appropriate in length                        Easy
# 10042       Appropriate in length  Neither easy nor difficult
# 10043       Appropriate in length  Neither easy nor difficult
#
# [10000 rows x 84 columns]

# %%
schema_df = pd.read_csv("survey_results_schema.csv", index_col="Column")

# %%
schema_df
# Out:
#                                                    QuestionText
# Column
# Respondent    Randomized respondent ID number (not in order ...
# MainBranch    Which of the following options best describes ...
# Hobbyist                                Do you code as a hobby?
# OpenSourcer         How often do you contribute to open source?
# OpenSource    How do you feel about the quality of open sour...
# ...                                                         ...
# Sexuality     Which of the following do you currently identi...
# Ethnicity     Which of the following do you identify as? Ple...
# Dependents    Do you have any dependents (e.g., children, el...
# SurveyLength  How do you feel about the length of the survey...
# SurveyEase    How easy or difficult was this survey to compl...
#
# [85 rows x 1 columns]

# %%
schema_df.loc['MgrIdiot', 'QuestionText']
# Out:
# 'How confident are you that your manager knows what they’re doing?'

# %%
schema_df.sort_index(inplace=True)

# %%
schema_df
# Out:
#                                                     QuestionText
# Column
# Age            What is your age (in years)? If you prefer not...
# Age1stCode     At what age did you write your first line of c...
# BetterLife     Do you think people born today will have a bet...
# BlockchainIs   Blockchain / cryptocurrency technology is prim...
# BlockchainOrg  How is your organization thinking about or imp...
# ...                                                          ...
# WorkPlan                 How structured or planned is your work?
# WorkRemote                       How often do you work remotely?
# WorkWeekHrs     On average, how many hours per week do you work?
# YearsCode      Including any education, how many years have y...
# YearsCodePro   How many years have you coded professionally (...
#
# [85 rows x 1 columns]
